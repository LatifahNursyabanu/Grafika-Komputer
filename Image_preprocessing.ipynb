# %% [markdown]
# #Image Preprocesing

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
img_path = '/content/ISIC_1728564.jpg'
img = image.load_img(img_path, target_size = (244,244))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 243.5, 243.5, -0.5)

# %%
def DataGen(datagen):
    data = img_to_array(img)
    samples = expand_dims(data, 0)
    print(samples.shape)
    it = datagen.flow(samples, batch_size=1)
    
    for i in range(4):
        plt.subplots(nrows=1, ncols=1, figsize =(5,5))
        batch = it.next()
        image = batch[0].astype('uint32')
        plt.imshow(image)
    plt.show()

# %%
datagen = ImageDataGenerator(width_shift_range=0.3)
print("width_shift_range")
DataGen(datagen)
# Out:
# width_shift_range
# (1, 244, 244, 3)

# %%
datagen = ImageDataGenerator(height_shift_range=0.3)
print("height_shift_range")
DataGen(datagen)
# Out:
# height_shift_range
# (1, 244, 244, 3)

# %%
datagen = ImageDataGenerator(rotation_range=90)
print("rotation_range")
DataGen(datagen)
# Out:
# rotation_range
# (1, 244, 244, 3)

# %%
datagen = ImageDataGenerator(rescale = 1/255, fill_mode = 'nearest')
print("rescale")
DataGen(datagen)
# Out:
# rescale
# (1, 244, 244, 3)

# %%
datagen = ImageDataGenerator(horizontal_flip=True)
print("horizontal_flip")
DataGen(datagen)
# Out:
# horizontal_flip
# (1, 244, 244, 3)

# %%
datagen = ImageDataGenerator(brightness_range=[0.2,1.0])
print("brightness_range")
DataGen(datagen)
# Out:
# brightness_range
# (1, 244, 244, 3)

# %%
datagen = ImageDataGenerator(zoom_range=[0.5,1.0])
print("zoom_range")
DataGen(datagen)
# Out:
# zoom_range
# (1, 244, 244, 3)

# %%
datagen = ImageDataGenerator(shear_range=0.9)
print("shear_range")
DataGen(datagen)
# Out:
# shear_range
# (1, 244, 244, 3)

# %%
datagen = ImageDataGenerator(vertical_flip=True)
print("vertical_flip")
DataGen(datagen)
# Out:
# vertical_flip
# (1, 244, 244, 3)

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    #featurewise_center=False,
    #samplewise_center=False,
    #featurewise_std_normalization=False,
    #samplewise_std_normalization=False,
    rotation_range=90,
    width_shift_range=0.3,
    height_shift_range=0.3,
    brightness_range=[0.2,1.0],
    #shear_range=0.2,
    zoom_range=[0.5,1.0],
    #channel_shift_range=0.0,
    horizontal_flip=True,
    vertical_flip=True,
    rescale=1/255)

# %%
#path = '/content/drive/MyDrive/minidata/oversampling/train'
#image = image_generator.flow_from_directory(path, batch_size=1)
#print(image)
# Out:
# Found 5402 images belonging to 2 classes.
# ...
